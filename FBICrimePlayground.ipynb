# %%
import requests
import json
import pandas as pd
import numpy as np
from config import govt

# %%
# url = "https://api.usa.gov/crime/fbi/ucr/"
# api_key = f"&api_key={govt}"
# query = "agencies/count/states/offenses/CA/counties/06059?"

# %%
# data = requests.get(f"{url}{query}&api_key={govt}").json()

# %%
# data
# Out:
# {'pagination': {'count': 0, 'page': 0, 'pages': 0, 'per_page': 10},
#  'results': []}

# %%
# data = requests.get("https://api.usa.gov/crime/fbi/ucr/agencies/count/states/offenses/CA/counties/06059?page=1&per_page=10&output=json&api_key=" + govt)

# %%
# data.json()
# Out:
# {'pagination': {'count': 0, 'page': 0, 'pages': 0, 'per_page': 10},
#  'results': []}

# %% [markdown]
# #### The FBI API doesn't appear to have county data for california in it yet, so lets use data downloaded from the FBI website https://ucr.fbi.gov/crime-in-the-u.s
# I tried here too https://crime-data-explorer.fr.cloud.gov/api#!/counties/get_agencies_count_states_offenses_state_abbr_counties_fips_code let me know if any of you can get it working!

# %%
county_file_name = "Raw_Data/Crime/Table_8_Offenses_Known_to_Law_Enforcement_California_by_Metropolitan_and_Nonmetropolitan_Counties_2016.xls"
county_excel = pd.read_excel(county_file_name)
city_file_name = "Raw_Data/Crime/Table_6_Offenses_Known_to_Law_Enforcement_California_by_City_2016.xls"
city_excel = pd.read_excel(city_file_name)
college_file_name = "Raw_Data/Crime/Table_7_Offenses_Known_to_Law_Enforcement_California_by_University_and_College_2016.xls"
college_excel = pd.read_excel(college_file_name)

# %%
county_excel
# Out:
#                                               Table 8       Unnamed: 1  \
# 0                                          CALIFORNIA              NaN
# 1                   Offenses Known to Law Enforcement              NaN
# 2   by Metropolitan and Nonmetropolitan Counties, ...              NaN
# 3   [The data shown in this table do not reflect c...              NaN
# 4                       Metropolitan/ Nonmetropolitan           County
# 5                               Metropolitan Counties          Alameda
# 6                                                 NaN            Butte
# 7                                                 NaN     Contra Costa
# 8                                                 NaN        El Dorado
# 9                                                 NaN           Fresno
# 10                                                NaN         Imperial
# 11                                                NaN             Kern
# ...

# %%
city_excel
# Out:
#                                                Table 6  Unnamed: 1  \
# 0                                           CALIFORNIA         NaN
# 1                    Offenses Known to Law Enforcement         NaN
# 2                                        by City, 2016         NaN
# 3                                                 City  Population
# 4                                             Adelanto       33479
# 5                                         Agoura Hills       21032
# 6                                              Alameda       79597
# 7                                               Albany       19975
# 8                                             Alhambra       86035
# 9                                          Aliso Viejo       50604
# 10                                             Alturas        2549
# 11                                    American Canyon        20746
# 12                                             Anaheim      353504
# ...

# %%
college_excel
# Out:
#                                               Table 7  \
# 0                                          CALIFORNIA
# 1                  Offenses Known to Law Enforcement
# 2                     by University and College, 2016
# 3                                 University/College
# 4                               Allan Hancock College
# 5           California State Polytechnic University:
# 6                                                 NaN
# 7                       California State University:
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
